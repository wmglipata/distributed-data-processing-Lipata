# %% [markdown]
# <a href="https://colab.research.google.com/github/wmglipata/distributed-data-processing-Lipata/blob/main/distributed_data_activity_lipata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PART I: SETUP (Cloud Environment)**

# %% [markdown]
# ## **Step 1: Open Google Colab**

# %% [markdown]
# ## **Step 2: Install and Initialize PySpark**

# %%
# !pip install pyspark

from pyspark.sql import SparkSession

spark = SparkSession.builder \
.appName("Distributed Data Processing Activity") \
.getOrCreate()

# %% [markdown]
# # **PART II: BIG DATA PROCESSING**

# %% [markdown]
# ## **Step 3: Load a Dataset**

# %%
from pyspark.sql.functions import col

df = spark.read.csv("sample_data/california_housing_test.csv", header=True, inferSchema=True)

df.show(5)
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |  -122.05|   37.37|              27.0|     3885.0|         661.0|    1537.0|     606.0|       6.6085|          344700.0|
# |   -118.3|   34.26|              43.0|     1510.0|         310.0|     809.0|     277.0|        3.599|          176500.0|
# |  -117.81|   33.78|              27.0|     3589.0|         507.0|    1484.0|     495.0|       5.7934|          270500.0|
# |  -118.36|   33.82|              28.0|       67.0|          15.0|      49.0|      11.0|       6.1359|          330000.0|
# |  -119.67|   36.33|              19.0|     1241.0|         244.0|     850.0|     237.0|       2.9375|           81700.0|
# ...

# %% [markdown]
# **Is the data processed sequentially or distributed?**
# - The data was processed in a distributed manner.
#
# **What does Spark do internally?**
# - Spark acts as the distributor for worker cores when reading the CSV. It slices the data into partitions and hands a small stack of rows to each of the workers to read at the same time, otherwise known as Distributed Processing. Beyond just splitting the work, Spark also uses Lazy Evaluation, meaning it doesn't actually start moving the data until an action is called like .show(). This allows it to build an optimized plan(Directed Acyclic Graph) first. Once it starts, Spark performs these calculations In-Memory (RAM) rather than constantly writing to the slow hard drive, which is why it can process thousands of rows in the time it takes standard Python to read just a few.

# %% [markdown]
# ## **Step 4: Perform Distributed Operations**

# %% [markdown]
# ### **Filter Data**

# %%
filtered_df = df.filter(col("median_house_value") > 90000)
filtered_df.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |  -122.05|   37.37|              27.0|     3885.0|         661.0|    1537.0|     606.0|       6.6085|          344700.0|
# |   -118.3|   34.26|              43.0|     1510.0|         310.0|     809.0|     277.0|        3.599|          176500.0|
# |  -117.81|   33.78|              27.0|     3589.0|         507.0|    1484.0|     495.0|       5.7934|          270500.0|
# |  -118.36|   33.82|              28.0|       67.0|          15.0|      49.0|      11.0|       6.1359|          330000.0|
# |  -120.65|   35.48|              19.0|     2310.0|         471.0|    1341.0|     441.0|        3.225|          166900.0|
# ...

# %% [markdown]
# (filtered values > 90,000 instead of 100 to since 100 is too small to filter anything meaningful)

# %% [markdown]
# # **PART III: PERFORMANCE AND SCALABILITY DISCUSSION**

# %% [markdown]
# # **PART IV: CLOUD COMPUTING ANALYSIS**
